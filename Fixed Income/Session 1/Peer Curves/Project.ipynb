# %% [markdown]
# <a></a>
# <div style="border-radius: 10px; border: 1px solid #0F9CF5; background-color: #232323; white-space: nowrap;">
#     <p style="margin-top: -10px; margin-bottom: 0px; margin-left: 10px; font-size: 1.15em; padding: 10px; overflow: hidden;">
#         <span style="color: orange; font-size: 2em;">&#9432;  </span>
#         Click the <span style="color: orange;">Run All</span> <img style="max-height: 1.5em; border: 1px solid orange;" src="img/RunAll.png" /> button in the toolbar above to run the code in this notebook
#     </p>
# </div>

# %% [markdown]
# # Credit Peer Curve Analysis
#
# This app allows users to perform credit relative value analysis on a selected issuer. Begin by selecting a company & comparison universe, and click "Analyze." The dashboard displays an aggregated term structure of peer universes for the selected company. Use the tabs to investigate individual constituents with interactive visualizations.

# %% [markdown]
# ## &#x1f4fa; Webinar Link
#
# This application is accompanied by a webinar which you can [view here](https://blinks.bloomberg.com/screens/PLYR%20VOD%20358998883).

# %%
# Running the App
import bql
import importlib
import App
import BQL_Util
import UI
import UtilityWidgets
# %load_ext autoreload
# %autoreload 2

bq = bql.Service()
importlib.reload(App)
importlib.reload(BQL_Util)
importlib.reload(UI)
importlib.reload(UtilityWidgets)
bql_util = BQL_Util.BQL_Util(bq)
app = App.App(bql_util)
app.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
